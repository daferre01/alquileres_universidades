# %%
import pandas as pd 
casas=pd.read_csv('universidades/casas.csv')

# %%
casas
# Out:
#       Unnamed: 0       ciudad  \
# 0              0      Arteixo
# 1              0   Ortigueira
# 2              0   Pontevedra
# 3              0   Pontevedra
# 4              0   Pontevedra
# ...          ...          ...
# 1717           0     A Coruña
# 1718           0         Lugo
# 1719           0       Nigran
# 1720           0   Pontevedra
# 1721           0         Vigo
#
#                                                  titulo  \
# 0                 Alquiler de Ático en calle moucho, 23
# 1                   Alquiler de Piso en Lugar Feira, 68
# 2               Alquiler de Piso en fernando olmedo s/n
# 3       Alquiler de Piso en avenida das Corvaceiras, 40
# 4              Alquiler de Piso en avenida de Vigo, 108
# ...                                                 ...
# 1717                      Alquiler de Piso en Os Mallos
# 1718           Alquiler de Piso en avenida de Magoi, 49
# 1719  Alquiler de Casa o chalet independiente en Panxón
# ...

# %%
casas2=casas[['ciudad','m2','precio']]

# %%
casas2['m2']=casas2['m2'].str.replace(' m²', '')
# Out:
# C:\Users\david.fernandezrebor\AppData\Local\Temp\ipykernel_21312\2745253728.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   casas2['m2']=casas2['m2'].str.replace(' m²', '')

# %%
casas2.to_excel('universidades/casas2.xlsx')

# %%
casas2.groupby(['ciudad']).mean()
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File c:\Users\david.fernandezrebor\AppData\Local\miniconda3\envs\bigdata\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...
